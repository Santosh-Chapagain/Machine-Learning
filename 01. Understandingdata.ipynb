# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Acer\\OneDrive\\Desktop\\Data Science\\netflix_titles.csv')

# %% [markdown]
# ## 1. How big is the data ?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## 2.How data looklike?

# %%
df.sample(5) ## It provide random data from dataset.
# Out:
#      show_id     type                                   title       director  \
# 7318   s7319    Movie  Little Singham Bandarpur Mein Hu Ha Hu            NaN
# 997     s998  TV Show   Life in Color with David Attenborough            NaN
# 4586   s4587    Movie                               Mugamoodi        Mysskin
# 2053   s2054  TV Show                         Young Wallander            NaN
# 7917   s7918    Movie                                   Sadma  Balu Mahendra
#
#                                                    cast  \
# 7318  Anamaya Verma, Ganesh Divekar, Jigna Bharadhwa...
# 997                                  David Attenborough
# 4586  Jiiva, Pooja Hegde, Narain, Nasser, Girish Kar...
# 2053  Adam Pålsson, Richard Dillane, Leanne Best, El...
# 7917  Kamal Hassan, Sridevi, Silk Smitha, Gulshan Gr...
#
#                         country         date_added  release_year rating  \
# 7318                        NaN      July 11, 2019          2019  TV-Y7
# ...

# %% [markdown]
# ## 3. what is the datatype of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## 4. Are there missing value ?

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Mathematical Values

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Are Duplicates ?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## How is correlation between cols?

# %%
df.corr() ## This will show the correlation between different numerical features in the dataset.
