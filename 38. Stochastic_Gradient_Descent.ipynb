# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x,y = load_diabetes(return_X_y=True)

# %%
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test , y_pred)
# Out:
# 0.4526027629719197

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [  37.90402135 -241.96436231  542.42875852  347.70384391 -931.48884588
#   518.06227698  163.41998299  275.31790158  736.1988589    48.67065743]
# 151.34560453985995

# %% [markdown]
# ## Making own SGDregressor

# %%
class sgdregressor:

    def __init__(self, learning_rate=0.01, epochs=100):

        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, x_train, y_train):
        # init your coefs
        self.intercept_ = 0
        self.coef_ = np.ones(x_train.shape[1])

        for i in range(self.epochs):
            for j in range(x_train.shape[0]):
                idx = np.random.randint(0 , x_train.shape[0])
                
                y_hat = np.dot(x_train[idx], self.coef_) + self.intercept_
                
                intercept_der = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                coef_der = -2 * np.dot((y_train[idx] - y_hat), x_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)

            print(self.intercept_, self.coef_)

    def predict(self, x_test):
        return np.dot(x_test, self.coef_) + self.intercept_

# %%
sgd = sgdregressor(learning_rate=0.01, epochs=40)

# %%
sgd.fit(x_train , y_train)
# Out:
# 159.86837502924396 [ 9.72466108  1.1164705  18.29703769 15.99048569  6.6844936   5.10640825
#  -8.06846692 10.80270154 16.78275568 10.46794141]
# 152.66469299457714 [ 14.32303237   1.82441737  32.15434953  24.45625563  10.18397343
#    8.40823362 -18.49096269  22.70270454  28.99798037  20.28635882]
# 159.273520432861 [ 16.59922892   1.29641813  47.48191292  35.39161959  14.93897387
#   12.60152691 -29.03093985  34.04497225  42.70397415  28.88010113]
# 147.57466553147114 [ 20.12857728   1.24216189  59.64640666  45.76825548  22.29289146
#   18.39119064 -37.87201007  45.24327565  56.99692928  37.55998433]
# 148.79512645480904 [ 25.08821238   0.92153645  71.23167263  55.40290134  26.4198098
#   21.48967408 -46.30656444  55.03323942  69.04538683  45.51335817]
# 157.68910984899165 [ 28.58516173  -2.40107795  82.93784813  63.64793419  28.64460012
#   22.47864043 -51.75354008  59.92450893  77.87324346  52.94029638]
# ...

# %%
y_pred = sgd.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4280726665574791

# %% [markdown]
# ## Using Sklearn SGDregressor class

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(max_iter=100 , learning_rate='constant',eta0 = 0.01)

# %%
sgd.fit(x_train , y_train)
# Out:
# c:\Users\Acer\anaconda3\envs\santoshenv\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1579: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred = sgd.predict(x_test)

# %%
r2_score(y_test , y_pred)
# Out:
# 0.4393130072701106

# %% [markdown]
# # Testing in different dataset

# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\Acer\OneDrive\Desktop\Machine Learning\CSV\diabetes-dataset.csv")

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
x = df.iloc[: , 0:8]
y = df.iloc[: , -1]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age
# 0                     0.127   47
# 1                     0.233   23
# 2                     0.630   31
# 3                     0.365   24
# 4                     0.536   21

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
sgd2 = make_pipeline(
    StandardScaler(),
    SGDRegressor(
        max_iter=20000,
        tol=1e-5,
        eta0=0.0001,
        learning_rate='adaptive',
        alpha=0.0001,
        penalty='l2',
        random_state=42
    )
)

# %%
sgd2.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor',
#                  SGDRegressor(eta0=0.0001, learning_rate='adaptive',
#                               max_iter=20000, random_state=42, tol=1e-05))])

# %%
y_pred = sgd2.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.2904254288543474

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import GridSearchCV

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("sgd", SGDRegressor(max_iter=20000, tol=1e-5, random_state=42, shuffle=True))
])

param_grid = {
    "sgd__eta0": [1e-3, 1e-4, 1e-5],           # start with these
    "sgd__learning_rate": ["invscaling", "adaptive", "optimal"],
    "sgd__alpha": [1e-4, 1e-5, 1e-6],          # regularization strength
    "sgd__penalty": ["l2"],                    # keep l2 for stability
}

gs = GridSearchCV(pipe, param_grid, scoring="r2", cv=5, n_jobs=-1, verbose=1)
gs.fit(x_train, y_train)

print("Best params:", gs.best_params_)
print("Best CV R2:", gs.best_score_)
print("Test R2:", r2_score(y_test, gs.predict(x_test)))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best params: {'sgd__alpha': 0.0001, 'sgd__eta0': 0.0001, 'sgd__learning_rate': 'adaptive', 'sgd__penalty': 'l2'}
# Best CV R2: 0.2768978465950275
# Test R2: 0.2904254288543474
